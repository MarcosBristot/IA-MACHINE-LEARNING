# %% [markdown]
# # Projeto Nanodegree: Modelo Preditivo de Evasão de Estudantes
#
# **Objetivo:** Construir um modelo preditivo da evasão de estudantes em um curso online síncrono.
#
# **Contexto:** A PensComp, uma organização educacional, promove cursos online síncronos e gratuitos para desenvolver habilidades de pensamento computacional em estudantes do 5º ao 9º ano do Ensino Fundamental. Observa-se variação no engajamento dos estudantes com a plataforma Moodle, e postula-se que alunos mais engajados demonstram melhor aprendizado, desempenho e menor taxa de evasão.
#
# Este notebook seguirá as etapas de um projeto de Machine Learning, desde a definição do problema até a exportação do modelo final.

# %%
import pandas as pd

df_treino = pd.read_csv("dados_projeto_evasao_treino.csv")

# %%
 # 2. Obter as dimensões (linhas, colunas)
print("--- 2. Dimensões dos Dados (Linhas, Colunas) ---")
print(f"Shape: {df_treino.shape}")
print(f"O conjunto de treino possui {df_treino.shape[0]} linhas e {df_treino.shape[1]} colunas.\n")
# Out:
# --- 2. Dimensões dos Dados (Linhas, Colunas) ---
# Shape: (400, 37)
# O conjunto de treino possui 400 linhas e 37 colunas.

# %%
# 3. Verificar os tipos de dados
print("--- 3. Tipos de Dados das Colunas ---")
print(df_treino.dtypes)
print("\n")
# Out:
# --- 3. Tipos de Dados das Colunas ---
# Unnamed: 0                                int64
# ds_cidade_usuario                        object
# ts_primeiro_acesso                        int64
# ts_ultimo_acesso                          int64
# nr_dias_desde_primeiro_acesso             int64
# nr_dias_desde_ultimo_acesso               int64
# nr_atividades_sinalizadas                 int64
# nr_atividades_mapeadas                    int64
# nr_discussoes_forum_postadas              int64
# nr_questionarios_abandonados              int64
# nr_questionarios_finalizados              int64
# vl_medio_tempo_questionario             float64
# vl_medio_tempo_questionario_avaliado    float64
# vl_desempenho_questionario              float64
# nr_intervalos_uso                       float64
# nr_dias_uso                               int64
# vl_medio_atividade_diaria               float64
# vl_engajamento_usuario_por_intervalo    float64
# vl_engajamento_usuario_intradia         float64
# nr_interacoes_usuario                     int64
# nr_dias_engajamento_discussao             int64
# nr_dias_engajamento_questionario          int64
# nr_engajamento_discussao                  int64
# nr_engajamento_questionario               int64
# nr_questoes_respondidas                   int64
# nr_questoes_corretas                      int64
# nr_questoes_erradas                       int64
# nr_questoes_parciais                      int64
# vl_desempenho_usuario                   float64
# vl_media_questoes_por_dia               float64
# vl_engajamento_notas                    float64
# nr_itens_avaliados                        int64
# nr_itens_nao_respondidos                  int64
# vl_media_notas                          float64
# nr_submissoes_codigo                      int64
# vl_media_submissoes_codigo              float64
# vl_submissoes_por_dias_ativos           float64
# dtype: object

# %%
 # 4. Procurar por valores ausentes
print("--- 4. Contagem de Valores Ausentes por Coluna ---")
missing_values = df_treino.isnull().sum()
# Filtrar para mostrar apenas colunas com valores ausentes, se houver
missing_values_filtered = missing_values[missing_values > 0]
if not missing_values_filtered.empty:
    print("Colunas com valores ausentes e suas contagens:")
    print(missing_values_filtered)
    print(f"\nPorcentagem de Valores Ausentes (para colunas com ausentes):")
    print((missing_values_filtered / len(df_treino)) * 100)
else:
    print("Não há valores ausentes neste conjunto de dados.")
print("\n")
# Out:
# --- 4. Contagem de Valores Ausentes por Coluna ---
# Colunas com valores ausentes e suas contagens:
# ds_cidade_usuario                        54
# vl_medio_tempo_questionario             289
# vl_medio_tempo_questionario_avaliado    293
# vl_desempenho_questionario              373
# nr_intervalos_uso                       191
# vl_medio_atividade_diaria               191
# vl_engajamento_usuario_por_intervalo    371
# vl_engajamento_usuario_intradia         371
# vl_desempenho_usuario                   287
# vl_media_questoes_por_dia               339
# vl_engajamento_notas                    339
# vl_media_notas                          287
# vl_media_submissoes_codigo              396
# vl_submissoes_por_dias_ativos           392
# dtype: int64
#
# Porcentagem de Valores Ausentes (para colunas com ausentes):
# ds_cidade_usuario                       13.50
# vl_medio_tempo_questionario             72.25
# vl_medio_tempo_questionario_avaliado    73.25
# vl_desempenho_questionario              93.25
# nr_intervalos_uso                       47.75
# vl_medio_atividade_diaria               47.75
# vl_engajamento_usuario_por_intervalo    92.75
# vl_engajamento_usuario_intradia         92.75
# vl_desempenho_usuario                   71.75
# vl_media_questoes_por_dia               84.75
# vl_engajamento_notas                    84.75
# vl_media_notas                          71.75
# vl_media_submissoes_codigo              99.00
# vl_submissoes_por_dias_ativos           98.00
# dtype: float64

# %%
 # 5. Obter estatísticas básicas
print("--- 5. Estatísticas Descritivas (para colunas numéricas) ---")
# .T para transpor, facilitando a leitura
print(df_treino.describe(include='all').T) # include='all' para incluir colunas não numéricas também
print("\n")
# Out:
# --- 5. Estatísticas Descritivas (para colunas numéricas) ---
#                                       count unique       top freq  \
# Unnamed: 0                            400.0    NaN       NaN  NaN
# ds_cidade_usuario                       346     10  Campinas  314
# ts_primeiro_acesso                    400.0    NaN       NaN  NaN
# ts_ultimo_acesso                      400.0    NaN       NaN  NaN
# nr_dias_desde_primeiro_acesso         400.0    NaN       NaN  NaN
# nr_dias_desde_ultimo_acesso           400.0    NaN       NaN  NaN
# nr_atividades_sinalizadas             400.0    NaN       NaN  NaN
# nr_atividades_mapeadas                400.0    NaN       NaN  NaN
# nr_discussoes_forum_postadas          400.0    NaN       NaN  NaN
# nr_questionarios_abandonados          400.0    NaN       NaN  NaN
# nr_questionarios_finalizados          400.0    NaN       NaN  NaN
# vl_medio_tempo_questionario           111.0    NaN       NaN  NaN
# vl_medio_tempo_questionario_avaliado  107.0    NaN       NaN  NaN
# vl_desempenho_questionario             27.0    NaN       NaN  NaN
# nr_intervalos_uso                     209.0    NaN       NaN  NaN
# nr_dias_uso                           400.0    NaN       NaN  NaN
# vl_medio_atividade_diaria             209.0    NaN       NaN  NaN
# vl_engajamento_usuario_por_intervalo   29.0    NaN       NaN  NaN
# vl_engajamento_usuario_intradia        29.0    NaN       NaN  NaN
# nr_interacoes_usuario                 400.0    NaN       NaN  NaN
# nr_dias_engajamento_discussao         400.0    NaN       NaN  NaN
# nr_dias_engajamento_questionario      400.0    NaN       NaN  NaN
# nr_engajamento_discussao              400.0    NaN       NaN  NaN
# nr_engajamento_questionario           400.0    NaN       NaN  NaN
# nr_questoes_respondidas               400.0    NaN       NaN  NaN
# nr_questoes_corretas                  400.0    NaN       NaN  NaN
# nr_questoes_erradas                   400.0    NaN       NaN  NaN
# nr_questoes_parciais                  400.0    NaN       NaN  NaN
# vl_desempenho_usuario                 113.0    NaN       NaN  NaN
# vl_media_questoes_por_dia              61.0    NaN       NaN  NaN
# vl_engajamento_notas                   61.0    NaN       NaN  NaN
# nr_itens_avaliados                    400.0    NaN       NaN  NaN
# nr_itens_nao_respondidos              400.0    NaN       NaN  NaN
# vl_media_notas                        113.0    NaN       NaN  NaN
# nr_submissoes_codigo                  400.0    NaN       NaN  NaN
# vl_media_submissoes_codigo              4.0    NaN       NaN  NaN
# vl_submissoes_por_dias_ativos           8.0    NaN       NaN  NaN
#
#                                                 mean               std  \
# Unnamed: 0                                  248.0275        140.580382
# ds_cidade_usuario                                NaN               NaN
# ts_primeiro_acesso                    864795845.0675  844528549.248133
# ts_ultimo_acesso                        866456004.13  846134549.757039
# nr_dias_desde_primeiro_acesso              9602.6675       9774.754241
# nr_dias_desde_ultimo_acesso                 9583.465       9793.330251
# nr_atividades_sinalizadas                     0.1775           1.22464
# nr_atividades_mapeadas                        0.9475          5.036184
# nr_discussoes_forum_postadas                   0.345          2.840095
# nr_questionarios_abandonados                   0.035          0.271956
# nr_questionarios_finalizados                   1.445          4.569922
# vl_medio_tempo_questionario             30625.595567       79011.37398
# vl_medio_tempo_questionario_avaliado    43281.982789       102916.7112
# vl_desempenho_questionario                   71.1391         24.795189
# nr_intervalos_uso                          53.181818        103.727664
# nr_dias_uso                                   5.3125         18.992937
# vl_medio_atividade_diaria                  15.992799         21.547344
# vl_engajamento_usuario_por_intervalo       29.834703         15.954499
# vl_engajamento_usuario_intradia            56.718514         41.130135
# nr_interacoes_usuario                         5.3125         18.992937
# nr_dias_engajamento_discussao                  1.255          5.162034
# nr_dias_engajamento_questionario              2.4075          9.057402
# nr_engajamento_discussao                       7.555         46.800402
# nr_engajamento_questionario                    58.94        214.012288
# nr_questoes_respondidas                      21.8325         56.079959
# nr_questoes_corretas                          15.975         45.719307
# nr_questoes_erradas                             2.22          4.942943
# nr_questoes_parciais                          0.2575          1.024117
# vl_desempenho_usuario                       0.876987          0.256726
# vl_media_questoes_por_dia                   0.709287          0.883716
# vl_engajamento_notas                        0.438528          0.383358
# nr_itens_avaliados                            2.4075          7.610272
# nr_itens_nao_respondidos                     22.2125           60.1802
# vl_media_notas                              0.875059          0.253001
# nr_submissoes_codigo                           0.535          4.720645
# vl_media_submissoes_codigo                    6.7143               0.0
# vl_submissoes_por_dias_ativos               11.08335          4.914363
#
#                                            min        25%           50%  \
# Unnamed: 0                                 1.0      131.5         245.5
# ds_cidade_usuario                          NaN        NaN           NaN
# ts_primeiro_acesso                         0.0        0.0  1661414432.5
# ts_ultimo_acesso                           0.0        0.0  1666093172.0
# nr_dias_desde_primeiro_acesso              4.0       20.0         382.5
# nr_dias_desde_ultimo_acesso                0.0       12.0         328.0
# nr_atividades_sinalizadas                  0.0        0.0           0.0
# nr_atividades_mapeadas                     0.0        0.0           0.0
# nr_discussoes_forum_postadas               0.0        0.0           0.0
# nr_questionarios_abandonados               0.0        0.0           0.0
# nr_questionarios_finalizados               0.0        0.0           0.0
# vl_medio_tempo_questionario               18.0      776.5       1835.25
# vl_medio_tempo_questionario_avaliado      18.0      633.5        1454.5
# vl_desempenho_questionario            6.203996  71.666667     80.807229
# nr_intervalos_uso                          0.0        0.0           4.0
# nr_dias_uso                                0.0        0.0           1.0
# vl_medio_atividade_diaria               0.1708        5.0           9.0
# vl_engajamento_usuario_por_intervalo   13.9942    19.3662       24.4444
# vl_engajamento_usuario_intradia        26.4828    37.3273       42.1154
# nr_interacoes_usuario                      0.0        0.0           1.0
# nr_dias_engajamento_discussao              0.0        0.0           0.0
# nr_dias_engajamento_questionario           0.0        0.0           0.0
# nr_engajamento_discussao                   0.0        0.0           0.0
# nr_engajamento_questionario                0.0        0.0           0.0
# nr_questoes_respondidas                    0.0        0.0           0.0
# nr_questoes_corretas                       0.0        0.0           0.0
# nr_questoes_erradas                        0.0        0.0           0.0
# nr_questoes_parciais                       0.0        0.0           0.0
# vl_desempenho_usuario                      0.0   0.919434           1.0
# vl_media_questoes_por_dia               0.0128     0.2092           0.5
# vl_engajamento_notas                    0.0085     0.1172        0.3125
# nr_itens_avaliados                         0.0        0.0           0.0
# nr_itens_nao_respondidos                   0.0        0.0           0.0
# vl_media_notas                             0.0   0.919389           1.0
# nr_submissoes_codigo                       0.0        0.0           0.0
# vl_media_submissoes_codigo              6.7143     6.7143        6.7143
# vl_submissoes_por_dias_ativos              6.0       6.75      11.33335
#
#                                                75%           max
# Unnamed: 0                                  367.25         499.0
# ds_cidade_usuario                              NaN           NaN
# ts_primeiro_acesso                    1692747175.0  1694097360.0
# ts_ultimo_acesso                      1693433737.0  1694471124.0
# nr_dias_desde_primeiro_acesso              19612.0       19612.0
# nr_dias_desde_ultimo_acesso                19612.0       19612.0
# nr_atividades_sinalizadas                      0.0          11.0
# nr_atividades_mapeadas                         0.0          48.0
# nr_discussoes_forum_postadas                   0.0          39.0
# nr_questionarios_abandonados                   0.0           3.0
# nr_questionarios_finalizados                   1.0          27.0
# vl_medio_tempo_questionario             15294.0588      432769.5
# vl_medio_tempo_questionario_avaliado       14695.0      432769.5
# vl_desempenho_questionario                84.34398     93.423423
# nr_intervalos_uso                             25.0         390.0
# nr_dias_uso                                    2.0         181.0
# vl_medio_atividade_diaria                     19.0         111.0
# vl_engajamento_usuario_por_intervalo       46.2916       60.4167
# vl_engajamento_usuario_intradia            51.0909      191.7514
# nr_interacoes_usuario                          2.0         181.0
# nr_dias_engajamento_discussao                  0.0          58.0
# nr_dias_engajamento_questionario               1.0          88.0
# nr_engajamento_discussao                       0.0         619.0
# nr_engajamento_questionario                  34.25        1944.0
# nr_questoes_respondidas                       19.0         345.0
# nr_questoes_corretas                           1.0         290.0
# nr_questoes_erradas                            0.0          21.0
# nr_questoes_parciais                           0.0           9.0
# vl_desempenho_usuario                          1.0           1.0
# vl_media_questoes_por_dia                   0.9286          5.25
# vl_engajamento_notas                        0.6667        1.3333
# nr_itens_avaliados                             1.0          50.0
# nr_itens_nao_respondidos                     47.25         716.0
# vl_media_notas                                 1.0           1.0
# nr_submissoes_codigo                           0.0          47.0
# vl_media_submissoes_codigo                  6.7143        6.7143
# vl_submissoes_por_dias_ativos              15.6667       15.6667

# %%
# Out:
# --- 6. Examinar a Distribuição da Variável Alvo ---
# Para examinar a distribuição da variável alvo, primeiro preciso saber qual coluna representa a EVASÃO dos alunos.
# Por favor, informe o nome da coluna que contém os valores (por exemplo, 0 para não evasão e 1 para evasão).
# Assim que você me fornecer o nome da coluna, poderei mostrar sua distribuição e continuar a análise.

# %%
import pandas as pd

# --- ASSUMINDO QUE df_treino JÁ FOI CARREGADO COMO ANTES ---
# Se não, descomente a linha abaixo e ajuste o caminho do arquivo se necessário
# df_treino = pd.read_csv("dados_projeto_evasao_treino.csv")

# Definir o limiar de inatividade em dias
limiar_inactividade_dias = 60

# Criar a coluna alvo 'FL_EVASAO'
# 1 se nr_dias_desde_ultimo_acesso > limiar_inactividade_dias, senão 0
df_treino['FL_EVASAO'] = df_treino['nr_dias_desde_ultimo_acesso'].apply(lambda x: 1 if x > limiar_inactividade_dias else 0)

print(f"Coluna alvo 'FL_EVASAO' criada com limiar de {limiar_inactividade_dias} dias de inatividade.\n")

# --- 6. Examinar a Distribuição da Variável Alvo ('FL_EVASAO') ---
print("--- Distribuição da Variável Alvo (FL_EVASAO) ---")
evasao_counts = df_treino['FL_EVASAO'].value_counts()
evasao_percentages = df_treino['FL_EVASAO'].value_counts(normalize=True) * 100

print("Contagem de alunos por status de evasão:")
print(evasao_counts)
print("\nPorcentagem de alunos por status de evasão:")
print(evasao_percentages)

# Mostrar as primeiras linhas com a nova coluna para verificação
print("\n--- Primeiras linhas do DataFrame com a nova coluna FL_EVASAO ---")
print(df_treino[['nr_dias_desde_ultimo_acesso', 'FL_EVASAO']].head(10))

# Mostrar algumas estatísticas da coluna nr_dias_desde_ultimo_acesso para os dois grupos
print("\n--- Estatísticas de 'nr_dias_desde_ultimo_acesso' para cada grupo de FL_EVASAO ---")
print(df_treino.groupby('FL_EVASAO')['nr_dias_desde_ultimo_acesso'].describe())
# Out:
# Coluna alvo 'FL_EVASAO' criada com limiar de 60 dias de inatividade.
#
# --- Distribuição da Variável Alvo (FL_EVASAO) ---
# Contagem de alunos por status de evasão:
# FL_EVASAO
# 1    219
# 0    181
# Name: count, dtype: int64
#
# Porcentagem de alunos por status de evasão:
# FL_EVASAO
# 1    54.75
# 0    45.25
# Name: proportion, dtype: float64
#
# --- Primeiras linhas do DataFrame com a nova coluna FL_EVASAO ---
#    nr_dias_desde_ultimo_acesso  FL_EVASAO
# 0                        19612          1
# 1                        19612          1
# 2                        19612          1
# 3                            6          0
# 4                        19612          1
# 5                            6          0
# 6                        19612          1
# 7                           18          0
# 8                           13          0
# 9                           15          0
#
# --- Estatísticas de 'nr_dias_desde_ultimo_acesso' para cada grupo de FL_EVASAO ---
#            count          mean          std    min      25%      50%      75%  \
# FL_EVASAO
# 0          181.0     13.243094    12.110900    0.0      5.0     11.0     18.0
# 1          219.0  17493.100457  6053.660897  143.0  19612.0  19612.0  19612.0
#
#                max
# FL_EVASAO
# 0             49.0
# 1          19612.0
